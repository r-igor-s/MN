# %%
#Створіть двовимірний масив (матрицю) розміром 3x3, заповніть його значеннями
#випадкових дійсних чисел від 1 до 10.
import numpy as np

matrix = np.random.uniform(1, 10, (3, 3))

print(matrix)
# Out:
# [[8.35452272 6.65917898 9.90509178]
#  [2.37020439 6.68418168 5.7951278 ]
#  [8.34846378 8.42215775 7.86962818]]
