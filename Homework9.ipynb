# %% [markdown]
# <a href="https://colab.research.google.com/github/r-igor-s/MN/blob/main/Homework9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow import keras
import os

# %%
# 1. Завантажити датасет Fashion MNIST
fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Імена класів
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# 2. Роздрукувати 10 зображень
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
# 3. Підготовка даних (нормалізація)
x_train = (x_train / 255.0).astype("float32")
x_test  = (x_test  / 255.0).astype("float32")

# %%
model = models.Sequential([
    keras.Input(shape=(28, 28)),
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(10, activation='softmax')
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=3e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
cb = [
    tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6, verbose=1)
]

history = model.fit(
    x_train, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.1,
    callbacks=cb,
    verbose=1
)

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6063 - loss: 1.1765 - val_accuracy: 0.8243 - val_loss: 0.4958 - learning_rate: 3.0000e-04
# Epoch 2/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8086 - loss: 0.5566 - val_accuracy: 0.8482 - val_loss: 0.4205 - learning_rate: 3.0000e-04
# Epoch 3/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8340 - loss: 0.4755 - val_accuracy: 0.8563 - val_loss: 0.3905 - learning_rate: 3.0000e-04
# Epoch 4/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8487 - loss: 0.4322 - val_accuracy: 0.8635 - val_loss: 0.3718 - learning_rate: 3.0000e-04
# Epoch 5/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8582 - loss: 0.4028 - val_accuracy: 0.8695 - val_loss: 0.3586 - learning_rate: 3.0000e-04
# Epoch 6/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8621 - loss: 0.3880 - val_accuracy: 0.8727 - val_loss: 0.3494 - learning_rate: 3.0000e-04
# Epoch 7/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8668 - loss: 0.3718 - val_accuracy: 0.8765 - val_loss: 0.3404 - learning_rate: 3.0000e-04
# Epoch 8/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8736 - loss: 0.3555 - val_accuracy: 0.8737 - val_loss: 0.3439 - learning_rate: 3.0000e-04
# Epoch 9/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8765 - loss: 0.3490 - val_accuracy: 0.8772 - val_loss: 0.3342 - learning_rate: 3.0000e-04
# Epoch 10/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8778 - loss: 0.3402 - val_accuracy: 0.8812 - val_loss: 0.3245 - learning_rate: 3.0000e-04
# Epoch 11/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8826 - loss: 0.3243 - val_accuracy: 0.8827 - val_loss: 0.3213 - learning_rate: 3.0000e-04
# Epoch 12/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8838 - loss: 0.3260 - val_accuracy: 0.8838 - val_loss: 0.3231 - learning_rate: 3.0000e-04
# Epoch 13/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8894 - loss: 0.3114 - val_accuracy: 0.8850 - val_loss: 0.3151 - learning_rate: 3.0000e-04
# Epoch 14/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8915 - loss: 0.2987 - val_accuracy: 0.8850 - val_loss: 0.3176 - learning_rate: 3.0000e-04
# Epoch 15/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8906 - loss: 0.3026 - val_accuracy: 0.8883 - val_loss: 0.3065 - learning_rate: 3.0000e-04
# Epoch 16/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8932 - loss: 0.2945 - val_accuracy: 0.8877 - val_loss: 0.3124 - learning_rate: 3.0000e-04
# Epoch 17/50
# 421/422 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8932 - loss: 0.2916
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8932 - loss: 0.2916 - val_accuracy: 0.8905 - val_loss: 0.3072 - learning_rate: 3.0000e-04
# Epoch 18/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9003 - loss: 0.2757 - val_accuracy: 0.8885 - val_loss: 0.3012 - learning_rate: 1.5000e-04
# Epoch 19/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9036 - loss: 0.2682 - val_accuracy: 0.8912 - val_loss: 0.3082 - learning_rate: 1.5000e-04
# Epoch 20/50
# 419/422 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9073 - loss: 0.2616
# Epoch 20: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9072 - loss: 0.2617 - val_accuracy: 0.8918 - val_loss: 0.3012 - learning_rate: 1.5000e-04
# Epoch 21/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9060 - loss: 0.2566 - val_accuracy: 0.8913 - val_loss: 0.2969 - learning_rate: 7.5000e-05
# Epoch 22/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9076 - loss: 0.2564 - val_accuracy: 0.8927 - val_loss: 0.2968 - learning_rate: 7.5000e-05
# Epoch 23/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9053 - loss: 0.2577
# Epoch 23: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9053 - loss: 0.2577 - val_accuracy: 0.8927 - val_loss: 0.2980 - learning_rate: 7.5000e-05
# Epoch 24/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9119 - loss: 0.2436 - val_accuracy: 0.8932 - val_loss: 0.2958 - learning_rate: 3.7500e-05
# Epoch 25/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9096 - loss: 0.2500 - val_accuracy: 0.8945 - val_loss: 0.2957 - learning_rate: 3.7500e-05
# Epoch 26/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9114 - loss: 0.2463 - val_accuracy: 0.8943 - val_loss: 0.2970 - learning_rate: 3.7500e-05
# Epoch 27/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9107 - loss: 0.2450 - val_accuracy: 0.8945 - val_loss: 0.2945 - learning_rate: 3.7500e-05
# Epoch 28/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9103 - loss: 0.2483 - val_accuracy: 0.8927 - val_loss: 0.2964 - learning_rate: 3.7500e-05
# Epoch 29/50
# 419/422 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9135 - loss: 0.2403
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9135 - loss: 0.2403 - val_accuracy: 0.8925 - val_loss: 0.2947 - learning_rate: 3.7500e-05
# Epoch 30/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9107 - loss: 0.2449 - val_accuracy: 0.8938 - val_loss: 0.2959 - learning_rate: 1.8750e-05
# Test accuracy: 0.8877999782562256

# %%
# Виведення архітектури моделі
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 654,176 (2.50 MB)
#  Trainable params: 218,058 (851.79 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 436,118 (1.66 MB)

# %%
# 7. Збереження моделі на Google Диск
from google.colab import drive
drive.mount('/content/drive')
model.save('/content/drive/MyDrive/fashion_mnist_model.keras')
# Out:
# Mounted at /content/drive

# %%
# 8. Побудова графіків функції втрат і точності
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('Loss')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.title('Accuracy')
plt.grid(True)
plt.legend()

plt.show()

# %%
# 9. Виведення класифікаційного звіту
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
predictions = model.predict(x_test)

# Перетворюємо прогнози в мітки
predicted_labels = np.argmax(predictions, axis=1)

# Виведення класифікаційного звіту
print(classification_report(y_test, predicted_labels, target_names=class_names))
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.8878 - loss: 0.3141
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.83      0.84      0.84      1000
#      Trouser       0.99      0.97      0.98      1000
#     Pullover       0.82      0.79      0.80      1000
#        Dress       0.87      0.91      0.89      1000
#         Coat       0.79      0.83      0.81      1000
#       Sandal       0.97      0.97      0.97      1000
#        Shirt       0.72      0.67      0.70      1000
#      Sneaker       0.94      0.96      0.95      1000
#          Bag       0.97      0.97      0.97      1000
#   Ankle boot       0.97      0.96      0.96      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000

# %%
plt.figure(figsize=(15, 3))  # ширше полотно для зручності

for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap='gray')  # замість plt.cm.binary для кращої сумісності
    pred_label = class_names[predicted_labels[i]]
    true_label = class_names[y_test[i]]
    color = 'green' if predicted_labels[i] == y_test[i] else 'red'
    plt.xlabel(f"Pred:\n{pred_label}", color=color)
    plt.title(f"True:\n{true_label}", fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# Увага, точність має бути не менше 0.87

# %% [markdown]
# Завдання 2. Керас тюнер

# %%
# !pip install keras-tuner -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 8.6 MB/s eta 0:00:00

# %%
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from keras_tuner.tuners import RandomSearch

import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow import keras
import os

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(keras.Input(shape=(28, 28)))
    model.add(Flatten())

    # Додавання шарів, які будуть тюнуватися
    for i in range(hp.Int('num_layers', 1, 3)):
        model.add(Dense(units=hp.Int('units_' + str(i),
                                     min_value=32,
                                     max_value=512,
                                     step=32),
                        activation='relu',
                        kernel_regularizer=l2(0.001)))
        model.add(Dropout(0.2))

    model.add(Dense(10, activation='softmax'))

    model.compile(optimizer=keras.optimizers.Adam(
                      hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=3,
    executions_per_trial=1,
    directory='tuner_logs',
    project_name='fashion_mnist_classification'
)

# %%
# Визначення колбеків: рання зупинка та зниження швидкості навчання
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

# Пошук найкращої моделі за допомогою keras_tuner
tuner.search(x_train, y_train, epochs=50, validation_data=(x_test, y_test),
             callbacks=[early_stopping, reduce_lr])

# Отримання найкращої моделі
best_model = tuner.get_best_models(num_models=1)[0]
best_model.summary()

# Повторне тренування найкращої моделі
history = best_model.fit(
    x_train, y_train,
    epochs=50,
    validation_data=(x_test, y_test),
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Trial 3 Complete [00h 12m 14s]
# val_accuracy: 0.8906000256538391
#
# Best val_accuracy So Far: 0.891700029373169
# Total elapsed time: 00h 30m 07s
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 416)            │       326,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 416)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 160)            │        66,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         5,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 398,762 (1.52 MB)
#  Trainable params: 398,762 (1.52 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.8983 - loss: 0.3984 - val_accuracy: 0.8812 - val_loss: 0.4321 - learning_rate: 1.0000e-04
# Epoch 2/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.9014 - loss: 0.3987 - val_accuracy: 0.8844 - val_loss: 0.4283 - learning_rate: 1.0000e-04
# Epoch 3/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.9012 - loss: 0.3970 - val_accuracy: 0.8846 - val_loss: 0.4357 - learning_rate: 1.0000e-04
# Epoch 4/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.9013 - loss: 0.3958 - val_accuracy: 0.8823 - val_loss: 0.4356 - learning_rate: 1.0000e-04
# Epoch 5/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9002 - loss: 0.3963 - val_accuracy: 0.8872 - val_loss: 0.4206 - learning_rate: 1.0000e-04
# Epoch 6/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.8988 - loss: 0.3968 - val_accuracy: 0.8830 - val_loss: 0.4355 - learning_rate: 1.0000e-04
# Epoch 7/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8999 - loss: 0.3964 - val_accuracy: 0.8861 - val_loss: 0.4236 - learning_rate: 1.0000e-04
# Epoch 8/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.9004 - loss: 0.3913 - val_accuracy: 0.8878 - val_loss: 0.4227 - learning_rate: 1.0000e-04

# %%
# Оцінка моделі
test_loss, test_acc = best_model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)

# Побудова графіків функції втрат і точності
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

# Графік втрат
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Loss during training')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Графік точності
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('Accuracy during training')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8868 - loss: 0.4223
# Test accuracy: 0.8871999979019165
# Test loss: 0.4205717146396637
